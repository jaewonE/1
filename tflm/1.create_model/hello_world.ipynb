# %% [markdown]
# # TinyML 'Hello World' 시작하기: 모델 구축과 훈련

# %% [markdown]
# 모든 프로젝트의 시작점. 'Hello world'를 시작해보자. 본 과정을 진행하며 모델을 직접 만들고 훈련시킨 후 마이크로컨트롤러 프로그램에 통합하는 것까지 차례차례 수행해보자.

# %%
# Base Setup


# import library
import os
import sys
import math
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from matplotlib import rc as matplot_rc


# Path setup
main_path = '/Users/jaewone/developer/tflm/1.create_model'
images_path = os.path.join(main_path, 'images')
os.makedirs(images_path, exist_ok=True)

sys.path.append(main_path)


# graph setup for clean graph
# %matplotlib inline
matplot_rc('axes', labelsize=14)
matplot_rc('xtick', labelsize=12)
matplot_rc('ytick', labelsize=12)

def show_and_save_graph(fig_name, tight_layout=True, fig_extension="png", resolution=300):
    path = os.path.join(images_path, fig_name + "." + fig_extension)
    print("Save image:", fig_name)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)
    plt.show()


# Set seed
random_seed = 42
np.random.seed(random_seed)

# %% [markdown]
# ## 1. 문제 정의
#
# 문제 정의. 즉 하고자 하는 바를 먼저 정의하자.
#
# 아래와 같은 사인(sin) 함수와 유사한 **'사인파'** 데이터가 존재할 때 x값을 통하여 결과값인 y를 예측하는 모델을 만드는 것이다.
#
# 예를 들어 아래와 같은 사인파가 있을 때 입력값으로 x=0이 주어졌을 때 y=0이라는 결과값을 반환하는 모델을 만드는 것이 목표이다.

# %%
plt.figure(figsize=(14, 6))
x = np.arange(0, 6, 0.1)
y = np.sin(x)
plt.plot(x, y)
show_and_save_graph("sin_graph")
# Out:
# Save image: sin_graph

# %% [markdown]
# 먼저 sine 형태의 데이터를 생성해보자.

# %%
# Create sine dataset
plt.figure(figsize=(14, 6))

# 아래의 값만큼 데이터 샘플을 생성할 것이다.
SAMPLES = 1000

# 사인파 진폭의 범위인 0~2π 내에서 균일하게 분포된 난수 집합을 생성한다.
x_values = np.random.uniform(low=0, high=2*math.pi, size=SAMPLES)

# 값을 섞어서 생성된 값들이 순서를 따르지 않도록 한다.
np.random.shuffle(x_values)

# 해당 사인값을 계산한다
y_values = np.sin(x_values)
plt.plot(x_values, y_values, 'b.')
show_and_save_graph("simple_sin_plot")
# Out:
# Save image: simple_sin_plot

# %% [markdown]
# sine 그래프에 노이즈를 추가하여 실제 데이터와 유사한 데이터를 생성하자.

# %%
# 각 y 값에 임의의 작은 숫자를 추가한다.
y_values += 0.1 * np.random.randn(*y_values.shape)

# 그래프를 생성한다.
plt.figure(figsize=(14, 6))
plt.plot(x_values, y_values, 'b.')
show_and_save_graph('sine_plot_with_noise')
# Out:
# Save image: sine_plot_with_noise

# %% [markdown]
# 데이터를 train, validation, test로 나눈다.

# %%
# 훈련에 60%, 테스트에 20%, 검증에  20%를 사용한다.
# 각 항목의 인덱스를 계산한다.
TRAIN_SPLIT = int(0.6 * SAMPLES)
TEST_SPLIT = int(0.2 * SAMPLES + TRAIN_SPLIT)

# np.split을 사용하여 데이터를 세 부분으로 자른다.
# np.split의 두 번째 인수는 데이터가 분할되는 인덱스 배열이며,
# 우리는 두 개의 인덱스를 제공하므로 데이터는 세 개의 덩어리로 나뉠 것이다.
x_train, x_test, x_validate = np.split(x_values, [TRAIN_SPLIT, TEST_SPLIT])
y_train, y_test, y_validate = np.split(y_values, [TRAIN_SPLIT, TEST_SPLIT])

# 분할한 데이터를 합쳤을 때 원래의 사이즈와 같은지 재확인한다.
assert (x_train.size + x_validate.size + x_test.size) == SAMPLES

# 분할된 각 데이터들을 다른 색상으로 그래프에 표시한다.
plt.figure(figsize=(14, 6))
plt.plot(x_train, y_train, 'b.', label="Train")
plt.plot(x_test, y_test, 'r.', label="Test")
plt.plot(x_validate, y_validate, 'y.', label="Validate")
plt.legend()
show_and_save_graph('sine_plot_with_noise_split')
# Out:
# Save image: sine_plot_with_noise_split

# %% [markdown]
# 입력된 x값을 통해 y값을 예측하는 모델을 생성해보자.

# %%
# Create model1
# from tensorflow.keras import layers

# # Set model
# model_1 = tf.keras.Sequential([
#     layers.Dense(16, activation='relu', input_shape=(1,)),
#     layers.Dense(1)
# ])

# # compile model
# model_1.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

# # train model
# history_1 = model_1.fit(x_train, y_train, epochs=1000, batch_size=16,
#                         validation_data=(x_validate, y_validate))

# # 훈련과 검증 과정에서 예측값과 실제값 사이의 거리인 손실 그래프를 그린다.
# loss = history_1.history['loss']
# val_loss = history_1.history['val_loss']

# epochs = range(1, len(loss) + 1)

# plt.figure(figsize=(14, 6))
# plt.plot(epochs, loss, 'g.', label='Training loss')
# plt.plot(epochs, val_loss, 'b', label='Validation loss')
# plt.title('Training and validation loss')
# plt.xlabel('Epochs')
# plt.ylabel('Loss')
# plt.legend()
# show_and_save_graph('model_1_losses')

# # 모델을 사용하여 검증 데이터로부터 예측값 생성
# predictions = model_1.predict(x_train)

# # 테스트 데이터와 함께 예측값을 그래프로 표현
# plt.figure(figsize=(14, 6))
# plt.clf()
# plt.title('Training data predicted vs actual values')
# plt.plot(x_test, y_test, 'b.', label='Actual')
# plt.plot(x_train, predictions, 'r.', label='Predicted')
# plt.legend()
# show_and_save_graph('model_1_predictions')

"""
모델이 0 <= x <= 1.1 범위에서 적합한 예측을 수행하지만 나머지 부분에서 대체적으로 적합하지 않는 것을 확인할 수 있다.

모델에 사인파 함수의 전체 복잡성을 학습할 수있는 충분한 Capacity가 없기 때문에 지나치게 단순한 방식으로만 예측을 수행했기 때문에 1.1 이상의 범위에서 충분한 적합도가 보이지 않은 것으로 보인다.

이에 모델을 더 크게 만들어 Capacity를 증가시켜보자.
"""
# Out:
# '\n모델이 0 <= x <= 1.1 범위에서 적합한 예측을 수행하지만 나머지 부분에서 대체적으로 적합하지 않는 것을 확인할 수 있다.\n\n모델에 사인파 함수의 전체 복잡성을 학습할 수있는 충분한 Capacity가 없기 때문에 지나치게 단순한 방식으로만 예측을 수행했기 때문에 1.1 이상의 범위에서 충분한 적합도가 보이지 않은 것으로 보인다.\n\n이에 모델을 더 크게 만들어 Capacity를 증가시켜보자.\n'

# %%
from tensorflow.keras import layers

model_2 = tf.keras.Sequential([
    layers.Dense(16, activation='relu', input_shape=(1,)),
    layers.Dense(16, activation='relu'),
    layers.Dense(1),
])

# 표준 옵티마이저 및 손실 함수를 사용하여 회귀 모델을 컴파일
model_2.compile(optimizer='rmsprop', loss='mse', metrics=['mae'])

history_2 = model_2.fit(x_train, y_train, epochs=600, batch_size=16,
                        validation_data=(x_validate, y_validate))
# Out:
# Metal device set to: Apple M1
#
# systemMemory: 16.00 GB
# maxCacheSize: 5.33 GB
#
# Epoch 1/600
# 2023-09-29 08:00:29.312552: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-09-29 08:00:29.312681: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2023-09-29 08:00:29.463761: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 2023-09-29 08:00:29.734641: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 38/38 [==============================] - 1s 15ms/step - loss: 0.6164 - mae: 0.6861 - val_loss: 0.4796 - val_mae: 0.6122
# Epoch 2/600
# 10/38 [======>.......................] - ETA: 0s - loss: 0.4199 - mae: 0.5636
# 2023-09-29 08:00:30.445720: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 38/38 [==============================] - 0s 8ms/step - loss: 0.3879 - mae: 0.5319 - val_loss: 0.3994 - val_mae: 0.5363
# Epoch 3/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.3228 - mae: 0.4821 - val_loss: 0.3303 - val_mae: 0.4894
# Epoch 4/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.2685 - mae: 0.4423 - val_loss: 0.2716 - val_mae: 0.4467
# Epoch 5/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.2232 - mae: 0.4040 - val_loss: 0.2311 - val_mae: 0.4054
# Epoch 6/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1905 - mae: 0.3751 - val_loss: 0.1861 - val_mae: 0.3786
# Epoch 7/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1695 - mae: 0.3546 - val_loss: 0.1702 - val_mae: 0.3641
# Epoch 8/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1590 - mae: 0.3433 - val_loss: 0.1534 - val_mae: 0.3443
# Epoch 9/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1495 - mae: 0.3293 - val_loss: 0.1505 - val_mae: 0.3386
# Epoch 10/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1427 - mae: 0.3240 - val_loss: 0.1325 - val_mae: 0.3158
# Epoch 11/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1392 - mae: 0.3183 - val_loss: 0.1271 - val_mae: 0.3081
# Epoch 12/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1343 - mae: 0.3091 - val_loss: 0.1221 - val_mae: 0.2989
# Epoch 13/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.1301 - mae: 0.3026 - val_loss: 0.1229 - val_mae: 0.2998
# Epoch 14/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1279 - mae: 0.2990 - val_loss: 0.1212 - val_mae: 0.2962
# Epoch 15/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1240 - mae: 0.2941 - val_loss: 0.1077 - val_mae: 0.2754
# Epoch 16/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1201 - mae: 0.2857 - val_loss: 0.1054 - val_mae: 0.2731
# Epoch 17/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.1163 - mae: 0.2803 - val_loss: 0.1194 - val_mae: 0.2867
# Epoch 18/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1132 - mae: 0.2742 - val_loss: 0.1078 - val_mae: 0.2737
# Epoch 19/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1098 - mae: 0.2716 - val_loss: 0.0930 - val_mae: 0.2509
# Epoch 20/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.1048 - mae: 0.2603 - val_loss: 0.0935 - val_mae: 0.2515
# Epoch 21/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.1008 - mae: 0.2530 - val_loss: 0.0963 - val_mae: 0.2504
# Epoch 22/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0977 - mae: 0.2471 - val_loss: 0.0925 - val_mae: 0.2416
# Epoch 23/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0940 - mae: 0.2403 - val_loss: 0.0772 - val_mae: 0.2160
# Epoch 24/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0916 - mae: 0.2354 - val_loss: 0.0754 - val_mae: 0.2132
# Epoch 25/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0885 - mae: 0.2284 - val_loss: 0.0800 - val_mae: 0.2179
# Epoch 26/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0830 - mae: 0.2209 - val_loss: 0.0677 - val_mae: 0.1924
# Epoch 27/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0814 - mae: 0.2130 - val_loss: 0.0710 - val_mae: 0.2008
# Epoch 28/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0781 - mae: 0.2102 - val_loss: 0.0661 - val_mae: 0.1897
# Epoch 29/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0747 - mae: 0.2014 - val_loss: 0.0630 - val_mae: 0.1828
# Epoch 30/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0714 - mae: 0.1966 - val_loss: 0.0603 - val_mae: 0.1780
# Epoch 31/600
# 38/38 [==============================] - 0s 12ms/step - loss: 0.0692 - mae: 0.1929 - val_loss: 0.0576 - val_mae: 0.1695
# Epoch 32/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0657 - mae: 0.1844 - val_loss: 0.0554 - val_mae: 0.1659
# Epoch 33/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0639 - mae: 0.1797 - val_loss: 0.0545 - val_mae: 0.1658
# Epoch 34/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0614 - mae: 0.1763 - val_loss: 0.0531 - val_mae: 0.1652
# Epoch 35/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0598 - mae: 0.1743 - val_loss: 0.0531 - val_mae: 0.1647
# Epoch 36/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.
600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0102 - mae: 0.0811 - val_loss: 0.0168 - val_mae: 0.1004
# Epoch 227/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0819 - val_loss: 0.0114 - val_mae: 0.0848
# Epoch 228/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0106 - mae: 0.0813 - val_loss: 0.0142 - val_mae: 0.0936
# Epoch 229/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0791 - val_loss: 0.0115 - val_mae: 0.0852
# Epoch 230/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0108 - mae: 0.0818 - val_loss: 0.0115 - val_mae: 0.0844
# Epoch 231/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0813 - val_loss: 0.0130 - val_mae: 0.0900
# Epoch 232/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0821 - val_loss: 0.0118 - val_mae: 0.0853
# Epoch 233/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0815 - val_loss: 0.0123 - val_mae: 0.0872
# Epoch 234/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0102 - mae: 0.0802 - val_loss: 0.0122 - val_mae: 0.0877
# Epoch 235/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0103 - mae: 0.0802 - val_loss: 0.0117 - val_mae: 0.0851
# Epoch 236/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0104 - mae: 0.0804 - val_loss: 0.0112 - val_mae: 0.0840
# Epoch 237/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0800 - val_loss: 0.0158 - val_mae: 0.0998
# Epoch 238/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0106 - mae: 0.0823 - val_loss: 0.0117 - val_mae: 0.0860
# Epoch 239/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0803 - val_loss: 0.0133 - val_mae: 0.0912
# Epoch 240/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0806 - val_loss: 0.0164 - val_mae: 0.1033
# Epoch 241/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0817 - val_loss: 0.0115 - val_mae: 0.0851
# Epoch 242/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0805 - val_loss: 0.0139 - val_mae: 0.0925
# Epoch 243/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0811 - val_loss: 0.0129 - val_mae: 0.0886
# Epoch 244/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0109 - mae: 0.0817 - val_loss: 0.0123 - val_mae: 0.0867
# Epoch 245/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0792 - val_loss: 0.0127 - val_mae: 0.0890
# Epoch 246/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0103 - mae: 0.0812 - val_loss: 0.0235 - val_mae: 0.1220
# Epoch 247/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0818 - val_loss: 0.0126 - val_mae: 0.0893
# Epoch 248/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0816 - val_loss: 0.0178 - val_mae: 0.1043
# Epoch 249/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0815 - val_loss: 0.0117 - val_mae: 0.0848
# Epoch 250/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0804 - val_loss: 0.0145 - val_mae: 0.0936
# Epoch 251/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0817 - val_loss: 0.0116 - val_mae: 0.0856
# Epoch 252/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0790 - val_loss: 0.0128 - val_mae: 0.0900
# Epoch 253/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0813 - val_loss: 0.0120 - val_mae: 0.0878
# Epoch 254/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0827 - val_loss: 0.0116 - val_mae: 0.0849
# Epoch 255/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0790 - val_loss: 0.0110 - val_mae: 0.0832
# Epoch 256/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0106 - mae: 0.0825 - val_loss: 0.0133 - val_mae: 0.0904
# Epoch 257/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0822 - val_loss: 0.0165 - val_mae: 0.0984
# Epoch 258/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0811 - val_loss: 0.0118 - val_mae: 0.0863
# Epoch 259/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0810 - val_loss: 0.0124 - val_mae: 0.0873
# Epoch 260/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0802 - val_loss: 0.0148 - val_mae: 0.0980
# Epoch 261/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0802 - val_loss: 0.0122 - val_mae: 0.0878
# Epoch 262/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0818 - val_loss: 0.0116 - val_mae: 0.0858
# Epoch 263/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0811 - val_loss: 0.0113 - val_mae: 0.0839
# Epoch 264/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0803 - val_loss: 0.0124 - val_mae: 0.0890
# Epoch 265/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0800 - val_loss: 0.0135 - val_mae: 0.0927
# Epoch 266/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0803 - val_loss: 0.0111 - val_mae: 0.0833
# Epoch 267/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0108 - mae: 0.0830 - val_loss: 0.0118 - val_mae: 0.0863
# Epoch 268/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0799 - val_loss: 0.0183 - val_mae: 0.1085
# Epoch 269/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0110 - mae: 0.0834 - val_loss: 0.0122 - val_mae: 0.0873
# Epoch 270/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0790 - val_loss: 0.0115 - val_mae: 0.0850
# Epoch 271/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0785 - val_loss: 0.0116 - val_mae: 0.0854
# Epoch 272/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0106 - mae: 0.0819 - val_loss: 0.0116 - val_mae: 0.0854
# Epoch 273/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0810 - val_loss: 0.0117 - val_mae: 0.0855
# Epoch 274/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0783 - val_loss: 0.0118 - val_mae: 0.0853
# Epoch 275/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0110 - mae: 0.0834 - val_loss: 0.0115 - val_mae: 0.0852
# Epoch 276/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0811 - val_loss: 0.0115 - val_mae: 0.0857
# Epoch 277/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0807 - val_loss: 0.0122 - val_mae: 0.0882
# Epoch 278/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0107 - mae: 0.0831 - val_loss: 0.0122 - val_mae: 0.0865
# Epoch 279/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0821 - val_loss: 0.0123 - val_mae: 0.0884
# Epoch 280/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0806 - val_loss: 0.0137 - val_mae: 0.0939
# Epoch 281/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0804 - val_loss: 0.0161 - val_mae: 0.0996
# Epoch 282/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0821 - val_loss: 0.0132 - val_mae: 0.0914
# Epoch 283/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0786 - val_loss: 0.0115 - val_mae: 0.0851
# Epoch 284/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0103 - mae: 0.0814 - val_loss: 0.0134 - val_mae: 0.0907
# Epoch 285/600
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0102 - mae: 0.0808 - val_loss: 0.0112 - val_mae: 0.0842
# Epoch 286/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0098 - mae: 0.0787 - val_loss: 0.0143 - val_mae: 0.0937
# Epoch 287/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0102 - mae: 0.0802 - val_loss: 0.0115 - val_mae: 0.0848
# Epoch 288/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0814 - val_loss: 0.0125 - val_mae: 0.0886
# Epoch 289/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0098 - mae: 0.0799 - val_loss: 0.0141 - val_mae: 0.0921
# Epoch 290/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0819 - val_loss: 0.0122 - val_mae: 0.0883
# Epoch 291/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0800 - val_loss: 0.0116 - val_mae: 0.0853
# Epoch 292/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0106 - mae: 0.0812 - val_loss: 0.0127 - val_mae: 0.0880
# Epoch 293/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0104 - mae: 0.0816 - val_loss: 0.0129 - val_mae: 0.0907
# Epoch 294/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0104 - mae: 0.0802 - val_loss: 0.0114 - val_mae: 0.0842
# Epoch 295/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0101 - mae: 0.0786 - val_loss: 0.0164 - val_mae: 0.1010
# Epoch 296/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0815 - val_loss: 0.0117 - val_mae: 0.0853
# Epoch 297/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0797 - val_loss: 0.0116 - val_mae: 0.0855
# Epoch 298/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0815 - val_loss: 0.0126 - val_mae: 0.0893
# Epoch 299/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0806 - val_loss: 0.0118 - val_mae: 0.0851
# Epoch 300/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0815 - val_loss: 0.0127 - val_mae: 0.0882
# Epoch 301/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0815 - val_loss: 0.0147 - val_mae: 0.0962
# Epoch 302/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0099 - mae: 0.0805 - val_loss: 0.0114 - val_mae: 0.0848
# Epoch 303/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0820 - val_loss: 0.0118 - val_mae: 0.0865
# Epoch 304/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0811 - val_loss: 0.0115 - val_mae: 0.0854
# Epoch 305/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0809 - val_loss: 0.0126 - val_mae: 0.0889
# Epoch 306/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0827 - val_loss: 0.0120 - val_mae: 0.0872
# Epoch 307/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0810 - val_loss: 0.0118 - val_mae: 0.0852
# Epoch 308/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0108 - mae: 0.0829 - val_loss: 0.0135 - val_mae: 0.0926
# Epoch 309/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0809 - val_loss: 0.0125 - val_mae: 0.0888
# Epoch 310/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0818 - val_loss: 0.0124 - val_mae: 0.0876
# Epoch 311/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0806 - val_loss: 0.0140 - val_mae: 0.0945
# Epoch 312/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0108 - mae: 0.0833 - val_loss: 0.0112 - val_mae: 0.0838
# Epoch 313/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0799 - val_loss: 0.0116 - val_mae: 0.0854
# Epoch 314/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0103 - mae: 0.0815 - val_loss: 0.0140 - val_mae: 0.0944
# Epoch 315/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0785 - val_loss: 0.0127 - val_mae: 0.0885
# Epoch 316/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0103 - mae: 0.0817 - val_loss: 0.0166 - val_mae: 0.0996
# Epoch 317/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0102 - mae: 0.0799 - val_loss: 0.0112 - val_mae: 0.0841
# Epoch 318/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0800 - val_loss: 0.0119 - val_mae: 0.0865
# Epoch 319/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0804 - val_loss: 0.0123 - val_mae: 0.0872
# Epoch 320/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0804 - val_loss: 0.0115 - val_mae: 0.0846
# Epoch 321/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0806 - val_loss: 0.0115 - val_mae: 0.0854
# Epoch 322/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0816 - val_loss: 0.0131 - val_mae: 0.0905
# Epoch 323/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0799 - val_loss: 0.0137 - val_mae: 0.0936
# Epoch 324/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0104 - mae: 0.0815 - val_loss: 0.0127 - val_mae: 0.0881
# Epoch 325/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0107 - mae: 0.0812 - val_loss: 0.0111 - val_mae: 0.0837
# Epoch 326/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0811 - val_loss: 0.0113 - val_mae: 0.0844
# Epoch 327/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0803 - val_loss: 0.0113 - val_mae: 0.0848
# Epoch 328/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0105 - mae: 0.0811 - val_loss: 0.0127 - val_mae: 0.0893
# Epoch 329/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0803 - val_loss: 0.0154 - val_mae: 0.0985
# Epoch 330/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0110 - mae: 0.0836 - val_loss: 0.0125 - val_mae: 0.0888
# Epoch 331/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0800 - val_loss: 0.0128 - val_mae: 0.0902
# Epoch 332/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0105 - mae: 0.0821 - val_loss: 0.0117 - val_mae: 0.0853
# Epoch 333/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0795 - val_loss: 0.0132 - val_mae: 0.0919
# Epoch 334/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0803 - val_loss: 0.0127 - val_mae: 0.0895
# Epoch 335/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0783 - val_loss: 0.0116 - val_mae: 0.0856
# Epoch 336/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0799 - val_loss: 0.0133 - val_mae: 0.0910
# Epoch 337/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0104 - mae: 0.0803 - val_loss: 0.0117 - val_mae: 0.0859
# Epoch 338/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0809 - val_loss: 0.0138 - val_mae: 0.0928
# Epoch 339/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0822 - val_loss: 0.0133 - val_mae: 0.0913
# Epoch 340/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0815 - val_loss: 0.0115 - val_mae: 0.0856
# Epoch 341/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0806 - val_loss: 0.0120 - val_mae: 0.0865
# Epoch 342/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0817 - val_loss: 0.0128 - val_mae: 0.0904
# Epoch 343/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0799 - val_loss: 0.0128 - val_mae: 0.0889
# Epoch 344/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0814 - val_loss: 0.0111 - val_mae: 0.0837
# Epoch 345/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0809 - val_loss: 0.0115 - val_mae: 0.0851
# Epoch 346/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0811 - val_loss: 0.0117 - val_mae: 0.0863
# Epoch 347/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0804 - val_loss: 0.0131 - val_mae: 0.0899
# Epoch 348/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0807 - val_loss: 0.0136 - val_mae: 0.0922
# Epoch 349/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0794 - val_loss: 0.0109 - val_mae: 0.0828
# Epoch 350/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0814 - val_loss: 0.0155 - val_mae: 0.0993
# Epoch 351/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0102 - mae: 0.0802 - val_loss: 0.0142 - val_mae: 0.0943
# Epoch 352/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0807 - val_loss: 0.0114 - val_mae: 0.0842
# Epoch 353/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0103 - mae: 0.0811 - val_loss: 0.0116 - val_mae: 0.0859
# Epoch 354/600
# ...
# Epoch 481/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0096 - mae: 0.0781 - val_loss: 0.0112 - val_mae: 0.0830
# Epoch 482/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0810 - val_loss: 0.0124 - val_mae: 0.0874
# Epoch 483/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0806 - val_loss: 0.0140 - val_mae: 0.0923
# Epoch 484/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0799 - val_loss: 0.0114 - val_mae: 0.0850
# Epoch 485/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0789 - val_loss: 0.0142 - val_mae: 0.0930
# Epoch 486/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0794 - val_loss: 0.0149 - val_mae: 0.0956
# Epoch 487/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0795 - val_loss: 0.0117 - val_mae: 0.0857
# Epoch 488/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0791 - val_loss: 0.0135 - val_mae: 0.0912
# Epoch 489/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0103 - mae: 0.0803 - val_loss: 0.0118 - val_mae: 0.0859
# Epoch 490/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0796 - val_loss: 0.0121 - val_mae: 0.0867
# Epoch 491/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0796 - val_loss: 0.0128 - val_mae: 0.0885
# Epoch 492/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0105 - mae: 0.0819 - val_loss: 0.0108 - val_mae: 0.0821
# Epoch 493/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0785 - val_loss: 0.0116 - val_mae: 0.0854
# Epoch 494/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0792 - val_loss: 0.0111 - val_mae: 0.0831
# Epoch 495/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0791 - val_loss: 0.0113 - val_mae: 0.0838
# Epoch 496/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0811 - val_loss: 0.0132 - val_mae: 0.0909
# Epoch 497/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0798 - val_loss: 0.0122 - val_mae: 0.0877
# Epoch 498/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0792 - val_loss: 0.0122 - val_mae: 0.0864
# Epoch 499/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0801 - val_loss: 0.0115 - val_mae: 0.0855
# Epoch 500/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0794 - val_loss: 0.0129 - val_mae: 0.0884
# Epoch 501/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0803 - val_loss: 0.0114 - val_mae: 0.0850
# Epoch 502/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0787 - val_loss: 0.0129 - val_mae: 0.0903
# Epoch 503/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0801 - val_loss: 0.0128 - val_mae: 0.0894
# Epoch 504/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0803 - val_loss: 0.0122 - val_mae: 0.0884
# Epoch 505/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0804 - val_loss: 0.0142 - val_mae: 0.0949
# Epoch 506/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0801 - val_loss: 0.0116 - val_mae: 0.0847
# Epoch 507/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0805 - val_loss: 0.0117 - val_mae: 0.0864
# Epoch 508/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0097 - mae: 0.0785 - val_loss: 0.0120 - val_mae: 0.0862
# Epoch 509/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0787 - val_loss: 0.0113 - val_mae: 0.0843
# Epoch 510/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0097 - mae: 0.0793 - val_loss: 0.0132 - val_mae: 0.0890
# Epoch 511/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0792 - val_loss: 0.0130 - val_mae: 0.0901
# Epoch 512/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0802 - val_loss: 0.0129 - val_mae: 0.0901
# Epoch 513/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0783 - val_loss: 0.0125 - val_mae: 0.0891
# Epoch 514/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0103 - mae: 0.0811 - val_loss: 0.0127 - val_mae: 0.0885
# Epoch 515/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0097 - mae: 0.0787 - val_loss: 0.0121 - val_mae: 0.0871
# Epoch 516/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0101 - mae: 0.0796 - val_loss: 0.0128 - val_mae: 0.0891
# Epoch 517/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0105 - mae: 0.0814 - val_loss: 0.0133 - val_mae: 0.0904
# Epoch 518/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0100 - mae: 0.0787 - val_loss: 0.0121 - val_mae: 0.0873
# Epoch 519/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0806 - val_loss: 0.0140 - val_mae: 0.0920
# Epoch 520/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0097 - mae: 0.0775 - val_loss: 0.0121 - val_mae: 0.0866
# Epoch 521/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0800 - val_loss: 0.0121 - val_mae: 0.0872
# Epoch 522/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0106 - mae: 0.0821 - val_loss: 0.0113 - val_mae: 0.0843
# Epoch 523/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0101 - mae: 0.0794 - val_loss: 0.0121 - val_mae: 0.0868
# Epoch 524/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0103 - mae: 0.0806 - val_loss: 0.0121 - val_mae: 0.0869
# Epoch 525/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0794 - val_loss: 0.0135 - val_mae: 0.0896
# Epoch 526/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0801 - val_loss: 0.0117 - val_mae: 0.0860
# Epoch 527/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0797 - val_loss: 0.0112 - val_mae: 0.0840
# Epoch 528/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0780 - val_loss: 0.0116 - val_mae: 0.0855
# Epoch 529/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0794 - val_loss: 0.0116 - val_mae: 0.0855
# Epoch 530/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0801 - val_loss: 0.0111 - val_mae: 0.0837
# Epoch 531/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0797 - val_loss: 0.0112 - val_mae: 0.0836
# Epoch 532/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0096 - mae: 0.0774 - val_loss: 0.0136 - val_mae: 0.0916
# Epoch 533/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0803 - val_loss: 0.0124 - val_mae: 0.0884
# Epoch 534/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0798 - val_loss: 0.0115 - val_mae: 0.0854
# Epoch 535/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0788 - val_loss: 0.0118 - val_mae: 0.0864
# Epoch 536/600
# 38/38 [==============================] - 0s 12ms/step - loss: 0.0099 - mae: 0.0802 - val_loss: 0.0115 - val_mae: 0.0850
# Epoch 537/600
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0098 - mae: 0.0801 - val_loss: 0.0116 - val_mae: 0.0862
# Epoch 538/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0810 - val_loss: 0.0115 - val_mae: 0.0846
# Epoch 539/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0798 - val_loss: 0.0125 - val_mae: 0.0887
# Epoch 540/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0796 - val_loss: 0.0126 - val_mae: 0.0888
# Epoch 541/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0105 - mae: 0.0820 - val_loss: 0.0124 - val_mae: 0.0885
# Epoch 542/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0102 - mae: 0.0805 - val_loss: 0.0119 - val_mae: 0.0871
# Epoch 543/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0098 - mae: 0.0787 - val_loss: 0.0128 - val_mae: 0.0899
# Epoch 544/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0792 - val_loss: 0.0111 - val_mae: 0.0838
# Epoch 545/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0096 - mae: 0.0775 - val_loss: 0.0110 - val_mae: 0.0834
# Epoch 546/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0812 - val_loss: 0.0114 - val_mae: 0.0854
# Epoch 547/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0795 - val_loss: 0.0111 - val_mae: 0.0839
# Epoch 548/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0105 - mae: 0.0808 - val_loss: 0.0117 - val_mae: 0.0853
# Epoch 549/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0104 - mae: 0.0818 - val_loss: 0.0115 - val_mae: 0.0845
# Epoch 550/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0787 - val_loss: 0.0137 - val_mae: 0.0933
# Epoch 551/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0798 - val_loss: 0.0134 - val_mae: 0.0918
# Epoch 552/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0793 - val_loss: 0.0122 - val_mae: 0.0868
# Epoch 553/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0098 - mae: 0.0792 - val_loss: 0.0133 - val_mae: 0.0900
# Epoch 554/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0103 - mae: 0.0814 - val_loss: 0.0117 - val_mae: 0.0862
# Epoch 555/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0096 - mae: 0.0786 - val_loss: 0.0114 - val_mae: 0.0855
# Epoch 556/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0794 - val_loss: 0.0129 - val_mae: 0.0895
# Epoch 557/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0802 - val_loss: 0.0121 - val_mae: 0.0861
# Epoch 558/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0100 - mae: 0.0801 - val_loss: 0.0115 - val_mae: 0.0852
# Epoch 559/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0099 - mae: 0.0789 - val_loss: 0.0133 - val_mae: 0.0906
# Epoch 560/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0097 - mae: 0.0797 - val_loss: 0.0114 - val_mae: 0.0851
# Epoch 561/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0808 - val_loss: 0.0115 - val_mae: 0.0853
# Epoch 562/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0802 - val_loss: 0.0120 - val_mae: 0.0868
# Epoch 563/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0102 - mae: 0.0804 - val_loss: 0.0125 - val_mae: 0.0873
# Epoch 564/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0796 - val_loss: 0.0119 - val_mae: 0.0870
# Epoch 565/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0794 - val_loss: 0.0133 - val_mae: 0.0898
# Epoch 566/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0782 - val_loss: 0.0119 - val_mae: 0.0871
# Epoch 567/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0805 - val_loss: 0.0122 - val_mae: 0.0874
# Epoch 568/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0102 - mae: 0.0808 - val_loss: 0.0119 - val_mae: 0.0857
# Epoch 569/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0098 - mae: 0.0790 - val_loss: 0.0123 - val_mae: 0.0888
# Epoch 570/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0802 - val_loss: 0.0151 - val_mae: 0.0956
# Epoch 571/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0102 - mae: 0.0811 - val_loss: 0.0122 - val_mae: 0.0887
# Epoch 572/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0096 - mae: 0.0769 - val_loss: 0.0113 - val_mae: 0.0843
# Epoch 573/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0100 - mae: 0.0781 - val_loss: 0.0192 - val_mae: 0.1086
# Epoch 574/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0106 - mae: 0.0817 - val_loss: 0.0146 - val_mae: 0.0941
# Epoch 575/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0099 - mae: 0.0790 - val_loss: 0.0117 - val_mae: 0.0861
# Epoch 576/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0101 - mae: 0.0799 - val_loss: 0.0122 - val_mae: 0.0877
# Epoch 577/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0805 - val_loss: 0.0115 - val_mae: 0.0853
# Epoch 578/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0789 - val_loss: 0.0111 - val_mae: 0.0840
# Epoch 579/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0099 - mae: 0.0787 - val_loss: 0.0111 - val_mae: 0.0837
# Epoch 580/600
# 38/38 [==============================] - 0s 7ms/step - loss: 0.0101 - mae: 0.0799 - val_loss: 0.0142 - val_mae: 0.0939
# Epoch 581/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0097 - mae: 0.0779 - val_loss: 0.0113 - val_mae: 0.0849
# Epoch 582/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0099 - mae: 0.0790 - val_loss: 0.0149 - val_mae: 0.0966
# Epoch 583/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0099 - mae: 0.0793 - val_loss: 0.0119 - val_mae: 0.0868
# Epoch 584/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0100 - mae: 0.0792 - val_loss: 0.0119 - val_mae: 0.0862
# Epoch 585/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0103 - mae: 0.0812 - val_loss: 0.0127 - val_mae: 0.0892
# Epoch 586/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0792 - val_loss: 0.0113 - val_mae: 0.0841
# Epoch 587/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0786 - val_loss: 0.0154 - val_mae: 0.0958
# Epoch 588/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0799 - val_loss: 0.0161 - val_mae: 0.0992
# Epoch 589/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0100 - mae: 0.0796 - val_loss: 0.0114 - val_mae: 0.0849
# Epoch 590/600
# 38/38 [==============================] - 0s 8ms/step - loss: 0.0099 - mae: 0.0788 - val_loss: 0.0174 - val_mae: 0.1036
# Epoch 591/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0102 - mae: 0.0803 - val_loss: 0.0121 - val_mae: 0.0869
# Epoch 592/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0098 - mae: 0.0780 - val_loss: 0.0145 - val_mae: 0.0949
# Epoch 593/600
# 38/38 [==============================] - 0s 11ms/step - loss: 0.0100 - mae: 0.0800 - val_loss: 0.0120 - val_mae: 0.0857
# Epoch 594/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0099 - mae: 0.0798 - val_loss: 0.0115 - val_mae: 0.0849
# Epoch 595/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0104 - mae: 0.0812 - val_loss: 0.0109 - val_mae: 0.0827
# Epoch 596/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0099 - mae: 0.0789 - val_loss: 0.0119 - val_mae: 0.0857
# Epoch 597/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0104 - mae: 0.0811 - val_loss: 0.0114 - val_mae: 0.0843
# Epoch 598/600
# 38/38 [==============================] - 0s 10ms/step - loss: 0.0097 - mae: 0.0784 - val_loss: 0.0111 - val_mae: 0.0836
# Epoch 599/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0101 - mae: 0.0796 - val_loss: 0.0134 - val_mae: 0.0924
# Epoch 600/600
# 38/38 [==============================] - 0s 9ms/step - loss: 0.0100 - mae: 0.0800 - val_loss: 0.0136 - val_mae: 0.0919

# %%
# 테스트 데이터셋의 손실 계산 및 출력
loss = model_2.evaluate(x_test, y_test)

# 테스트 데이터셋 기반으로 예측
predictions = model_2.predict(x_test)

# 실제값에 대한 예측 그래프
plt.clf()
plt.figure(figsize=(14, 6))
plt.title('Comparison of predictions and actual values')
plt.plot(x_test, y_test, 'b.', label='Actual')
plt.plot(x_test, predictions, 'r.', label='Predicted')
plt.legend()
show_and_save_graph('model_2_predictions')
# Out:
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0142 - mae: 0.0976
# Save image: model_2_predictions
# 2023-09-29 08:03:33.588915: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %% [markdown]
# 자 이제 모델이 완성되었으니 tensorflow lite 모델로 변환해보자.

# %%
# 양자화 없이 모델을 텐서플로우 라이트 형식으로 변환
converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
tflite_model = converter.convert()

# 모델을 디스크에 저장
open("sine_model.tflite", "wb").write(tflite_model)

# 양자화하여 모델을 텐서플로우 라이트 형식으로 변환
converter = tf.lite.TFLiteConverter.from_keras_model(model_2)
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()

# 모델을 디스크에 저장
open("sine_model_quantized.tflite", "wb").write(tflite_model)
# Out:
# INFO:tensorflow:Assets written to: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmpl7c10v4u/assets
# 2023-09-29 08:03:34.343100: W tensorflow/python/util/util.cc:368] Sets are not currently considered sequences, but this may change in the future, so consider avoiding using them.
# 2023-09-29 08:03:35.669062: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-09-29 08:03:35.669079: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 2023-09-29 08:03:35.670058: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmpl7c10v4u
# 2023-09-29 08:03:35.670698: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-09-29 08:03:35.670704: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmpl7c10v4u
# 2023-09-29 08:03:35.673501: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-09-29 08:03:35.700793: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmpl7c10v4u
# 2023-09-29 08:03:35.708143: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 38087 microseconds.
# 2023-09-29 08:03:35.734536: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:237] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmp4uadrxi7/assets
# INFO:tensorflow:Assets written to: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmp4uadrxi7/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# 2023-09-29 08:03:37.125334: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:357] Ignored output_format.
# 2023-09-29 08:03:37.125345: W tensorflow/compiler/mlir/lite/python/tf_tfl_flatbuffer_helpers.cc:360] Ignored drop_control_dependency.
# WARNING:absl:Buffer deduplication procedure will be skipped when flatbuffer library is not properly loaded
# 2023-09-29 08:03:37.125422: I tensorflow/cc/saved_model/reader.cc:43] Reading SavedModel from: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmp4uadrxi7
# 2023-09-29 08:03:37.126046: I tensorflow/cc/saved_model/reader.cc:78] Reading meta graph with tags { serve }
# 2023-09-29 08:03:37.126051: I tensorflow/cc/saved_model/reader.cc:119] Reading SavedModel debug info (if present) from: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmp4uadrxi7
# 2023-09-29 08:03:37.128200: I tensorflow/cc/saved_model/loader.cc:228] Restoring SavedModel bundle.
# 2023-09-29 08:03:37.151054: I tensorflow/cc/saved_model/loader.cc:212] Running initialization op on SavedModel bundle at path: /var/folders/10/9_p98m6j42n84y4wmf_k0krc0000gn/T/tmp4uadrxi7
# 2023-09-29 08:03:37.158511: I tensorflow/cc/saved_model/loader.cc:301] SavedModel load for tags { serve }; Status: success: OK. Took 33089 microseconds.
# 2023-09-29 08:03:37.184850: I tensorflow/lite/tools/optimize/quantize_weights.cc:225] Skipping quantization of tensor sequential/dense/MatMul because it has fewer than 1024 elements (16).
# 2023-09-29 08:03:37.184862: I tensorflow/lite/tools/optimize/quantize_weights.cc:225] Skipping quantization of tensor sequential/dense_1/MatMul because it has fewer than 1024 elements (256).
# 2023-09-29 08:03:37.184865: I tensorflow/lite/tools/optimize/quantize_weights.cc:225] Skipping quantization of tensor sequential/dense_2/MatMul because it has fewer than 1024 elements (16).
# 3008

# %% [markdown]
# 양자화를 통해 tflite로 변환된 모델(tflite_model)과 기존 모델(model_2)의 성능을 비교해보자.

# %%
# 각 모델에 대한 인터프리터 인스턴스화.
sine_model = tf.lite.Interpreter('sine_model.tflite')
sine_model_quantized = tf.lite.Interpreter('sine_model_quantized.tflite')

# 각 모델에 대한 메모리 할당
sine_model.allocate_tensors()
sine_model_quantized.allocate_tensors()

# 입력과 결과 텐서에 대한 인덱스 가져오기
sine_model_input = sine_model.tensor(
    sine_model.get_input_details()[0]["index"])
sine_model_output = sine_model.tensor(
    sine_model.get_output_details()[0]["index"])
sine_model_quantized_input = sine_model_quantized.tensor(
    sine_model_quantized.get_input_details()[0]["index"])
sine_model_quantized_output = sine_model_quantized.tensor(
    sine_model_quantized.get_output_details()[0]["index"])

# 결과를 저장하기 위한 배열 생성
sine_model_predictions = np.empty(x_test.size)
sine_model_quantized_predictions = np.empty(x_test.size)

# 각 값에 대해 각 모델의 인터프리터를 실행하고 결과를 배열에 저장
for i in range(x_test.size):
    sine_model_input().fill(x_test[i])
    sine_model.invoke()
    sine_model_predictions[i] = sine_model_output()[0]

    sine_model_quantized_input().fill(x_test[i])
    sine_model_quantized.invoke()
    sine_model_quantized_predictions[i] = sine_model_quantized_output()[0]

# 데이터가 어떻게 정렬되는지 확인
plt.clf()
plt.figure(figsize=(14, 6))
plt.title('Comparison of various models against actual values')
plt.plot(x_test, y_test, 'bo', label='Actual')
plt.plot(x_test, predictions, 'ro', label='Original predictions')
plt.plot(x_test, sine_model_predictions, 'bx', label='Lite predictions')
plt.plot(x_test, sine_model_quantized_predictions,
         'gx', label='Lite quantized predictions')
plt.legend()
show_and_save_graph('model_comparisons')
# Out:
# Save image: model_comparisons

# %% [markdown]
# 비교 결과 모델의 크기가 가벼워졌음에도 불구하고 정확도는 크게 떨어지지 않았음을 확인할 수 있다.

# %% [markdown]
# 위 과정을 통해 변환된 tflite 모델을 C 소스 파일로 변환해주자. 변환된 C 소스 파일은 model_quant_tflite.txt 파일로 저장된다.

# %%
# xxd를 사용할 수 없을 경우, 설치한다.
# !apt-get -qq install xxd
# 파일을 C 소스파일로 저장 
import sys
sys.stdout = open('model_quant_tflite.txt','w')

# !xxd -i sine_model_quantized.tflite > sine_model_quantized.cc
# 소스파일을 출력
# !cat sine_model_quantized.cc
